# %%
list=[1,2,3,4,5]
print(list)
print(type(list))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
a=(1,2,3,4,5)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
set1={2,6,8,9,7,5}
print(set1)
print(type(set1))
# Out:
# {2, 5, 6, 7, 8, 9}
# <class 'set'>

# %%
dictionary={"name":"aakash","age":28}
print(dictionary)
print(type(dictionary))
# Out:
# {'name': 'aakash', 'age': 28}
# <class 'dict'>

# %%
list=[1,2,3,4,5]

# to add the data at last index
list.append(10)
print(list)

# insert function
# list.insert(indexposition,value)
list.insert(1,20)
print(list)
# Out:
# [1, 2, 3, 4, 5, 10]
# [1, 20, 2, 3, 4, 5, 10]
